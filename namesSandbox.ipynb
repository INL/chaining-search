# %% [markdown]
# # *Chaining search*: Names lexicon service demonstration
#
# Use this notebook to combine linguistic resources yourself: corpora, lexica and treebanks.
#  * Use methods from our library *chaininglib*, [described in the documentation](doc/_build/html/index.html)
#  * To get an idea of the possibilities and to copy code, go to the [Examples notebook](Examples.ipynb).
#  * If you encounter any bugs or errors, please let us know via our [GitHub issue tracker](https://github.com/INL/chaining-search/issues) or send an e-mail to servicedesk@ivdnt.org.

# %%
#import chaininglib

from chaininglib.search.CorpusQuery import *
from chaininglib.process.corpus import *
from chaininglib.ui.dfui import *
from chaininglib.search.LexiconQuery import *
from chaininglib.ui.dfui import display_df
from chaininglib.search.CorpusQuery import *
from chaininglib.search.LexiconQuery import *
from IPython.core.display import display, HTML
from chaininglib.search.corpusQueries import corpus_query
from chaininglib.process.lexicon import get_diamant_synonyms
from chaininglib.ui.dfui import display_df
import re

lexicon_name='nameslex'

names_lexicon=create_lexicon(lexicon_name)

def get_variants(search_word, max):
    df_lexicon = names_lexicon.query_type('expand').word(search_word).search().kwic()
    syns = df_lexicon['wordform'].tolist() 
    syns.append(search_word) 
    filtered_syns = [syn for syn in syns if len(syn) > 0 and re.match("^[a-zA-Z]+$", syn)]
    return filtered_syns[0:max]

def expanded_query(search_word, max):
    variants = get_variants(search_word, max)
    bigOr = '|'.join(variants)
    return corpus_query(word=bigOr,pos='NEPER')

def separate_variant_queries(search_word, max):
    variants = get_variants(search_word, max)
    variant_queries = [corpus_query(word=variant,pos='NEPER') for variant in variants]
    return variant_queries

def find_with_expanded_query(corpus,search_word, max_variants, max_results):
    query = expanded_query(search_word, max_variants)
    search_results = create_corpus(corpus).pattern(query).max_results(max_results).search().kwic()
    return search_results

def find_with_separate_queries(corpus,search_word, max_variants, max_results_per_variant):
    variant_queries = separate_variant_queries(search_word, max_variants)
    combined_results = pd.DataFrame()
    for one_query in variant_queries:
        kwic = create_corpus(corpus).pattern(one_query).max_results(max_results_per_variant).search().kwic()
        combined_results = combined_results.append(kwic)
    return combined_results

# %% [markdown]
# Lexicon service query types:
# * expand (get all word forms which are in a common paradigm with search_word)
# * get_wordforms (get all wordforms from the paradim of lemmata with lemma form search_word)
# * get_lemma_from_wordform (find lemmata l such that search_word belongs to the paradigm of l)
# * get_related_lemmata (find related lemmata to lemma with id lemma_id)
# * get_wordforms_from_lemma_id (get all wordforms from the paradim of lemmata with lemma id lemma_id)

# %% [markdown]
# # Expand query: from wordform to wordform

# %%
search_word='mathieu'

df_lexicon = names_lexicon.query_type('expand').word(search_word).search().kwic()

display_df(df_lexicon)
# Out:
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/expand?case_sensitive=false&tweaked_queries=true&database=nameslex&wordform=mathieu
#      query_lemma_id query_word query_pos     wordform
# 0                      mathieu
# 1                      mathieu                lemaheu
# 2                      mathieu                lemahie
# 3                      mathieu               lemahieu
# 4                      mathieu                lemahui
# 5                      mathieu                lemavie
# 6                      mathieu                maahijs
# 7                      mathieu               maarthis
# 8                      mathieu                  maate
# 9                      mathieu                 maatea
# 10                     mathieu               maatewes
# 11                     mathieu               maathäus
# 12                     mathieu                 maathe
# 13                     mathieu                maatheu
# 14                     mathieu               maatheus
# 15                     mathieu               maathias
# 16                     mathieu               maathijs
# 17                     mathieu                maatien
# 18                     mathieu                maatije
# 19                     mathieu                maatijs
# 20                     mathieu                maatina
# 21                     mathieu                 maatjr
# 22                     mathieu                 maatke
# 23                     mathieu              maatthias
# 24                     mathieu              maatthijs
# 25                     mathieu            maatthijsje
# 26                     mathieu                 machea
# 27                     mathieu                machius
# 28                     mathieu                    mad
# 29                     mathieu                madlain
# ...             ...        ...       ...          ...
# 1125                   mathieu                tissins
# 1126                   mathieu                tividad
# 1127                   mathieu                   tiza
# 1128                   mathieu                tjeuwke
# 1129                   mathieu              tjsalling
# 1130                   mathieu               tjsiegje
# 1131                   mathieu                toscain
# 1132                   mathieu              toscajana
# 1133                   mathieu                  toske
# 1134                   mathieu                 toskea
# 1135                   mathieu                 toskéa
# 1136                   mathieu                 tosked
# 1137                   mathieu                 toskje
# 1138                   mathieu                  ttijs
# 1139                   mathieu                 tuisje
# 1140                   mathieu                tuisman
# 1141                   mathieu                twiskje
# 1142                   mathieu                  tygje
# 1143                   mathieu                    tys
# 1144                   mathieu               tysciena
# 1145                   mathieu                 tysema
# 1146                   mathieu                  tysie
# 1147                   mathieu                 tysina
# 1148                   mathieu                  tysje
# 1149                   mathieu                  tyske
# 1150                   mathieu                tyssien
# 1151                   mathieu                tyssina
# 1152                   mathieu                tyssyna
# 1153                   mathieu                tysyena
# 1154                   mathieu                tyzanje
#
# [1155 rows x 4 columns]
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…

# %% [markdown]
# # Get lemma from wordform

# %%
search_word='jesse'

df_lexicon  = create_lexicon(lexicon_name).query_type('get_lemma_from_wordform').word(search_word).search().kwic()

display_df(df_lexicon)
# Out:
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/get_lemma_from_wordform?case_sensitive=false&tweaked_queries=true&database=nameslex&wordform=jesse
#      dataset lemma  lemma_id  pos
# 0  names_sns            8381
# 1   names_gn             435  F M
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…

# %% [markdown]
# # Get wordforms from lemma id

# %%
lex = create_lexicon(lexicon_name).query_type('get_wordforms_from_lemma_id').lemma_id('8381').search()

df_lexicon = lex.kwic()

display_df(df_lexicon)
# Out:
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/get_wordforms_from_lemma_id?case_sensitive=false&tweaked_queries=true&database=nameslex&lemma_id=8381
#     query_lemma_id query_word query_pos wordform
# 0             8381                          jees
# 1             8381                       jeessen
# 2             8381                         jehse
# 3             8381                           jes
# 4             8381                       jeschen
# 5             8381                        jeseer
# 6             8381                         jesel
# 7             8381                       jesella
# 8             8381                         jesen
# 9             8381                        jeseph
# 10            8381                         jeses
# 11            8381                        jesher
# 12            8381                         jeske
# 13            8381                        jesken
# 14            8381                        jeslen
# 15            8381                          jess
# 16            8381                         jesse
# 17            8381                         jessé
# 18            8381                         jessè
# 19            8381                        jessee
# 20            8381                        jessel
# 21            8381                        jessem
# 22            8381                        jessen
# 23            8381                       jessens
# 24            8381                        jesser
# 25            8381                        jesses
# 26            8381                        jezeer
# 27            8381                        jezeër
# 28            8381                         jezek
# 29            8381                         jezen
# 30            8381                         jezer
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…

# %% [markdown]
# # Get related lemmata

# %%
df_lexicon = names_lexicon.query_type('get_related_lemmata').lemma_id('8381').search().kwic()

display_df(df_lexicon)
# Out:
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/get_related_lemmata?case_sensitive=false&tweaked_queries=true&database=nameslex&lemma_id=8381
#   lemma  lemma_id pos relation
# 0            8480      synonym
# 1            8388      synonym
# 2            8381      synonym
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…

# %% [markdown]
# # Query expansie met names lexicon, zoek in zeebrieven

# %%
corpus= "zeebrieven"
search_word='jan'


        

#display(HTML('Naamsvarianten bij <b>' + search_word + '</b>: ' + ", ".join(syns[1:30])))


kwic = find_with_expanded_query(corpus,search_word, 500, 50)

display(HTML("<i>Results for expanded query </i>: " + str(len(kwic.index))))

display_df(kwic)


kwic = find_with_separate_queries(corpus,search_word, 30, 50)

display(HTML("<i>Results for separate queries </i>: " + str(len(kwic.index))))

display_df(kwic)
# Out:
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/expand?case_sensitive=false&tweaked_queries=true&database=nameslex&wordform=jan
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22ancko%7Canco%7Cancoch%7Cancolina%7Canko%7Ccohannes%7Ceijans%7Cgeiatje%7Cgian%7Cgianelli%7Cgianetti%7Cgiani%7Cgianiel%7Cgianni%7Cgiantten%7Cgijaan%7Cgioani%7Cgioanna%7Cgioanni%7Cgioannie%7Cgiofani%7Cgion%7Cgionani%7Cgionanni%7Cgioranni%7Cgiovan%7Cgiovana%7Cgiovani%7Cgiovanice%7Cgiovanna%7Cgiovanni%7Cgiovannie%7Cgiovannina%7Cgiovannio%7Cgiovanno%7Cgiuvanna%7Cgyon%7Cha%7Chaagt%7Chaagtje%7Chaan%7Chaana%7Chaaneman%7Chaanes%7Chaanke%7Chaanpje%7Chaansen%7Chaanskie%7Chaanstje%7Chaantie%7Chaantje%7Chaantke%7Chaantzen%7Chaanzen%7Chaemtje%7Chaenske%7Chaentje%7Chagnes%7Chagnus%7Chagte%7Chagteltje%7Chagtje%7Chalchen%7Chan%7Chanaatje%7Chananja%7Chanasia%7Chanasse%7Chanatasia%7Chanca%7Chance%7Chanchen%7Chanchien%7Chanchin%7Chancing%7Chancke%7Chancken%7Chanco%7Chand%7Chandden%7Chandje%7Chandle%7Chandsten%7Chandt%7Chandtie%7Chandtje%7Chane%7Chanedika%7Chanedriksje%7Chanel%7Chanelina%7Chanelore%7Chanenburg%7Chanes%7Chanesius%7Chanette%7Chanettie%7Changara%7Changen%7Changie%7Changien%7Chani%7Chania%7Chaniersken%7Chanigie%7Chanigje%7Chanigunda%7Chanimedes%7Chanimel%7Chanington%7Chanis%7Chanischeew%7Chaniske%7Chanja%7Chanje%7Chanjo%7Chanjoor%7Chanjorg%7Chanjuel%7Chanjurg%7Chank%7Chanka%7Chanke%7Chankea%7Chankiena%7Chankina%7Chankje%7Chankjen%7Chanko%7Chanktjen%7Chann%7Channa%7Channaatje%7Channaatjen%7Channacillen%7Channak%7Channamie%7Channanja%7Channanmis%7Channas%7Channatje%7Channawilhelmina%7Channchen%7Channcken%7Channe%7Channechie%7Channechien%7Channecillen%7Channegie%7Channegien%7Channegiena%7Channegij%7Channegje%7Channegjen%7Channeisien%7Channeka%7Channeke%7Channeken%7Channeklaas%7Channelau%7Channeliese%7Channelina%7Channelore%7Channema%7Channemie%7Channemine%7Channenchen%7Channens%7Channer%7Channes%7Channeschen%7Channesch
# 10                    gillesen sij ben gecoome van
# 11                        genaemt godt lof ben tot
# 12                  pietersen Varende op het schip
# 13            Pietersen Beminde man, naar Jonstige
# 14                          en hebben wij tot noch
# 15                         en aspelgren is ok tuys
# 16                        soo hem bij occasie vint
# 17
# 18                         van galen aen karsov om
# 19                            varen de op het sijp
# 20                         van galen aen karsov om
# 21                          en anten en alle goede
# 22              varende voor trompetter met vrient
# 23                       ick ul huijs frou neeltie
# 24                    bewaere en bescherme voor al
# 25                     die gaet nu op boonemaecken
# 26                         ioppen uven soon in den
# 27              luickesen kerremelc van moncke dam
# 28                      van haerlijm dije lijdt te
# 29                 sijckes van stavooren met vrijn
# 30                        sijckes ick u l lijefste
# 31                         gerrensen ijck laet u l
# 32                       heije ick ul seer beminde
# 33                  Hontum senden ontrent 27000 lb
# 34                  hus vrouwe van Iacob venduille
# 35  zij gheschreve een vrijendelijcke groetenijsse
# 36                            ate 25 lb koeret aen
# 37               poemrou aen gelen bloenke bijelle
# 38                       poemrou van 30 guelden en
# 39         ul moeder niet sonder traennen</anders>
# 40                  en Morjan zijn gesomeerdt voor
# 41                            al wat leert en onse
# 42                     genacht seggen en wi krigen
# 43                         en vaders en alle goede
# 44                       pont van eedam tot rotsel
# 45                 is Zieklijk & Zal menschelijker
# 46                        Petter Fimboe heb ik aen
# 47                     wont buijten de noort Poort
# 48                      Van der meij sou gekreegen
# 49                     wont buijten de noort poort
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/expand?case_sensitive=false&tweaked_queries=true&database=nameslex&wordform=jan
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22ancko%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22anco%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22ancoch%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22ancolina%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22anko%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22cohannes%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22eijans%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22geiatje%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gian%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gianelli%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gianetti%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22giani%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gianiel%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gianni%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22giantten%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gijaan%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gioani%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gioanna%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gioanni%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gioannie%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22giofani%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gion%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gionani%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gionanni%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22gioranni%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22giovan%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22giovana%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22giovani%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22giovanice%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/zeebrieven/hits?&number=50&first=0&patt=%5Bword%3D%22giovanna%22%20%26%20pos%3D%22NEPER%22%5D&filter=
# <i>Results for separate queries </i>: 0
# Empty DataFrame
# Columns: []
# Index: []
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…

# %%
corpus="opus"
query="[pos_head='VRB']"
search_results=create_corpus(corpus).pattern(query).max_results(33).search().kwic()
display_df(search_results)
# Out:
# Corpus Query url:http://brievenalsbuit.ato.ivdnt.org/blacklab-server/OPUS/hits?&number=33&first=0&patt=%5Bpos_head%3D%27VRB%27%5D&filter=
#                                left context    lemma 0  \
# 0                        hem niet uit om te      komen
# 1                      niet uit om te komen       eten
# 2                      uit om te komen eten       zijn
# 3                te komen eten zijn beesten     zullen
# 4              zijn beesten zullen nog meer      komen
# 5             beesten zullen nog meer komen      halen
# 6                    geen enkel spoor en ik     hebben
# 7                     ik heb een flinke kou     pakken
# 8                  een flinke kou gepakt Ik     kunnen
# 9                    kou gepakt Ik kan niet    wachten
# 10               weer terug op de Andromeda       zijn
# 11    Wie die kobalt-nikkel smokkelaars ook      mogen
# 12  die kobalt-nikkel smokkelaars ook mogen       zijn
# 13            smokkelaars ook mogen zijn ze       doen
# 14                  ze doen het wel grondig      laten
# 15                 het wel grondig Laten we      hopen
# 16                   dat het bij Beka beter       gaan
# 17               bij Beka beter ging Waarom     willen
# 18       wil iemand waardeloze stukken rots     stelen
# 19        en van zoveel planeten Waardeloos      weten
# 20    verschillende dingen kobalt en nikkel  gebruiken
# 21         dingen kobalt en nikkel gebruikt     kunnen
# 22         kobalt en nikkel gebruikt kunnen     worden
# 23       gebruikt kunnen worden Volgens mij     hebben
# 24                   jij rotsen in je hoofd     zullen
# 25                  ik je eens een kopstoot      geven
# 26                 geven zodat je het zeker      weten
# 27                    het zeker weet Och ik      weten
# 28                     ik weet het al zeker      horen
# 29       we in zware zwaartekracht werelden       zijn
# 30     in zware zwaartekracht werelden zijn     worden
# 31                 als eerste naar de grond    trekken
# 32        Het beledigen van een Nietzschean       zijn
#
#                                                                          pos 0  \
# 0                                                      VRB(finiteness=ger|inf)
# 1                                                      VRB(finiteness=ger|inf)
# 2                            VRB(finiteness=fin,mood=ind,tense=pres,number=pl)
# 3                            VRB(finiteness=fin,mood=ind,tense=pres,number=pl)
# 4                                                      VRB(finiteness=ger|inf)
# 5                                                      VRB(finiteness=ger|inf)
# 6                        VRB(finiteness=fin,mood=imp|ind,tense=pres,number=sg)
# 7                                              VRB(finiteness=part,tense=past)
# 8                        VRB(finiteness=fin,mood=imp|ind,tense=pres,number=sg)
# 9                                                      VRB(finiteness=ger|inf)
# 10                           VRB(finiteness=fin,mood=ind,tense=pres,number=pl)
# 11                           VRB(finiteness=fin,mood=ind,tense=pres,number=pl)
# 12                                                     VRB(finiteness=ger|inf)
# 13                           VRB(finiteness=fin,mood=ind,tense=pres,number=pl)
# 14                           VRB(finiteness=fin,mood=ind,tense=pres,number=pl)
# 15                           VRB(finiteness=fin,mood=ind,tense=pres,number=pl)
# 16                           VRB(finiteness=fin,mood=ind,tense=past,number=sg)
# 17                       VRB(finiteness=fin,mood=imp|ind,tense=pres,number=sg)
# 18                                                     VRB(finiteness=ger|inf)
# 19                       VRB(finiteness=fin,mood=imp|ind,tense=pres,number=sg)
# 20                                             VRB(finiteness=part,tense=past)
# 21                           VRB(finiteness=fin,mood=ind,tense=pres,number=pl)
# 22                                                     VRB(finiteness=ger|inf)
# 23                       VRB(finiteness=fin,mood=imp|ind,tense=pres,number=sg)
# 24                       VRB(finiteness=fin,mood=imp|ind,tense=pres,number=sg)
# 25                                                     VRB(finiteness=ger|inf)
# 26                       VRB(finiteness=fin,mood=imp|ind,tense=pres,number=sg)
# 27                       VRB(finiteness=fin,mood=imp|ind,tense=pres,number=sg)
# 28                       VRB(finiteness=fin,mood=imp|ind,tense=pres,number=sg)
# 29                           VRB(finiteness=fin,mood=ind,tense=pres,number=pl)
# 30  VRB(finiteness=fin,mood=ind,tense=pres,number=sg,person=2|3,formal=infl-t)
# 31                                             VRB(finiteness=part,tense=past)
# 32                       VRB(finiteness=fin,mood=imp|ind,tense=pres,number=sg)
#
#        word 0                          right context
# 0       komen           eten zijn beesten zullen nog
# 1        eten           zijn beesten zullen nog meer
# 2        zijn          beesten zullen nog meer komen
# 3      zullen              nog meer komen halen Hoge
# 4       komen       halen Hoge Priesteres Misabo Ahm
# 5       halen          Hoge Priesteres Misabo Ahm in
# 6         heb               een flinke kou gepakt Ik
# 7      gepakt                Ik kan niet wachten tot
# 8         kan               niet wachten tot we weer
# 9     wachten                   tot we weer terug op
# 10       zijn  Wie die kobalt-nikkel smokkelaars ook
# 11      mogen                   zijn ze doen het wel
# 12       zijn                ze doen het wel grondig
# 13       doen               het wel grondig Laten we
# 14      Laten                   we hopen dat het bij
# 15      hopen                 dat het bij Beka beter
# 16       ging   Waarom wil iemand waardeloze stukken
# 17        wil  iemand waardeloze stukken rots stelen
# 18     stelen      en van zoveel planeten Waardeloos
# 19       Weet          je wel voor hoeveel miljoenen
# 20   gebruikt          kunnen worden Volgens mij heb
# 21     kunnen             worden Volgens mij heb jij
# 22     worden             Volgens mij heb jij rotsen
# 23        heb                 jij rotsen in je hoofd
# 24        Zal                ik je eens een kopstoot
# 25      geven                zodat je het zeker weet
# 26       weet                     Och ik weet het al
# 27       weet                  het al zeker hoor Als
# 28       hoor          Als we in zware zwaartekracht
# 29       zijn                 wordt je hoofd dan als
# 30      wordt                je hoofd dan als eerste
# 31  getrokken      Het beledigen van een Nietzschean
# 32         is   niet bevorderlijk voor de menselijke
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…
