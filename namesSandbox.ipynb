# %% [markdown]
# # *Chaining search*: Sandbox
#
# Use this notebook to combine linguistic resources yourself: corpora, lexica and treebanks.
#  * Use methods from our library *chaininglib*, [described in the documentation](doc/_build/html/index.html)
#  * To get an idea of the possibilities and to copy code, go to the [Examples notebook](Examples.ipynb).
#  * If you encounter any bugs or errors, please let us know via our [GitHub issue tracker](https://github.com/INL/chaining-search/issues) or send an e-mail to servicedesk@ivdnt.org.

# %%
#import chaininglib

from chaininglib.search.CorpusQuery import *

from chaininglib.process.corpus import *

from chaininglib.ui.dfui import *

 

from chaininglib.search.LexiconQuery import *

from chaininglib.ui.dfui import display_df

from chaininglib.search.CorpusQuery import *
from chaininglib.search.LexiconQuery import *
from IPython.core.display import display, HTML
from chaininglib.search.corpusQueries import corpus_query
from chaininglib.process.lexicon import get_diamant_synonyms
from chaininglib.ui.dfui import display_df
import re

# %% [markdown]
# Lexicon service query types:
# * expand
# * get_wordforms
# * get_lemma_from_wordform
# * get_related_lemmata
# * get_wordforms_from_lemma_id
# * get_related_lemmata

# %%
lexicon_name='nameslex'

search_word='mathieu'

lex = create_lexicon(lexicon_name).query_type('expand').word(search_word).search()

df_lexicon = lex.kwic()

display_df(df_lexicon)
# Out:
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/expand?case_sensitive=false&tweaked_queries=true&database=nameslex&wordform=mathieu
#          wordform query_lemma_id query_pos query_word
# 0                                             mathieu
# 1         lemaheu                             mathieu
# 2         lemahie                             mathieu
# 3        lemahieu                             mathieu
# 4         lemahui                             mathieu
# 5         lemavie                             mathieu
# 6         maahijs                             mathieu
# 7        maarthis                             mathieu
# 8           maate                             mathieu
# 9          maatea                             mathieu
# 10       maatewes                             mathieu
# 11       maathäus                             mathieu
# 12         maathe                             mathieu
# 13        maatheu                             mathieu
# 14       maatheus                             mathieu
# 15       maathias                             mathieu
# 16       maathijs                             mathieu
# 17        maatien                             mathieu
# 18        maatije                             mathieu
# 19        maatijs                             mathieu
# 20        maatina                             mathieu
# 21         maatjr                             mathieu
# 22         maatke                             mathieu
# 23      maatthias                             mathieu
# 24      maatthijs                             mathieu
# 25    maatthijsje                             mathieu
# 26         machea                             mathieu
# 27        machius                             mathieu
# 28            mad                             mathieu
# 29        madlain                             mathieu
# ...           ...            ...       ...        ...
# 1125      tissins                             mathieu
# 1126      tividad                             mathieu
# 1127         tiza                             mathieu
# 1128      tjeuwke                             mathieu
# 1129    tjsalling                             mathieu
# 1130     tjsiegje                             mathieu
# 1131      toscain                             mathieu
# 1132    toscajana                             mathieu
# 1133        toske                             mathieu
# 1134       toskea                             mathieu
# 1135       toskéa                             mathieu
# 1136       tosked                             mathieu
# 1137       toskje                             mathieu
# 1138        ttijs                             mathieu
# 1139       tuisje                             mathieu
# 1140      tuisman                             mathieu
# 1141      twiskje                             mathieu
# 1142        tygje                             mathieu
# 1143          tys                             mathieu
# 1144     tysciena                             mathieu
# 1145       tysema                             mathieu
# 1146        tysie                             mathieu
# 1147       tysina                             mathieu
# 1148        tysje                             mathieu
# 1149        tyske                             mathieu
# 1150      tyssien                             mathieu
# 1151      tyssina                             mathieu
# 1152      tyssyna                             mathieu
# 1153      tysyena                             mathieu
# 1154      tyzanje                             mathieu
#
# [1155 rows x 4 columns]
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…

# %%
lexicon_name='nameslex'

search_word='jesse'

lex = create_lexicon(lexicon_name).query_type('get_lemma_from_wordform').word(search_word).search()

df_lexicon = lex.kwic()

display_df(df_lexicon)
# Out:
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/get_lemma_from_wordform?case_sensitive=false&tweaked_queries=true&database=nameslex&wordform=jesse
#      dataset lemma  lemma_id  pos
# 0  names_sns            8381
# 1   names_gn             435  F M
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…

# %%
lex = create_lexicon(lexicon_name).query_type('get_wordforms_from_lemma_id').lemma_id('8381').search()

df_lexicon = lex.kwic()

display_df(df_lexicon)
# Out:
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/get_wordforms_from_lemma_id?case_sensitive=false&tweaked_queries=true&database=nameslex&lemma_id=8381
#    wordform  query_lemma_id query_pos query_word
# 0      jees            8381
# 1   jeessen            8381
# 2     jehse            8381
# 3       jes            8381
# 4   jeschen            8381
# 5    jeseer            8381
# 6     jesel            8381
# 7   jesella            8381
# 8     jesen            8381
# 9    jeseph            8381
# 10    jeses            8381
# 11   jesher            8381
# 12    jeske            8381
# 13   jesken            8381
# 14   jeslen            8381
# 15     jess            8381
# 16    jesse            8381
# 17    jessé            8381
# 18    jessè            8381
# 19   jessee            8381
# 20   jessel            8381
# 21   jessem            8381
# 22   jessen            8381
# 23  jessens            8381
# 24   jesser            8381
# 25   jesses            8381
# 26   jezeer            8381
# 27   jezeër            8381
# 28    jezek            8381
# 29    jezen            8381
# 30    jezer            8381
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…

# %%
lex = create_lexicon(lexicon_name).query_type('get_related_lemmata').lemma_id('8381').search()

df_lexicon = lex.kwic()

display_df(df_lexicon)
# Out:
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/get_related_lemmata?case_sensitive=false&tweaked_queries=true&database=nameslex&lemma_id=8381
#   lemma  lemma_id pos relation
# 0            8480      synonym
# 1            8388      synonym
# 2            8381      synonym
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…

# %%
# Query expansie met names lexicon


corpus= "zeebrieven"

lexicon_name='nameslex'

search_word='jan'



# First, lookup synonyms in Names lexicon
lq = create_lexicon(lexicon_name).query_type('expand').word(search_word).search()
df_lexicon = lq.kwic()

syns = df_lexicon['wordform'].tolist() # get the wordform column from df_lexicon
syns.append(search_word) # Also add search word itself
display(HTML('Naamsvarianten bij <b>' + search_word + '</b>: ' + ", ".join(syns[1:30])))

# Search for all synonyms in corpus
## Create queries: search by lemma
filtered_syns = [syn for syn in syns if len(syn) > 0 and re.match("^[a-zA-Z]+$", syn)]
syns_queries = [corpus_query(word=syn) for syn in filtered_syns][0:30]
## display(syns_queries)
## Search for all synonyms in corpus
df = pd.DataFrame()
# separate queries (slow)
if 0==1:
    for one_pattern in syns_queries:
        print("Searching for pattern: " + one_pattern)
        cq = create_corpus(corpus).pattern(one_pattern).max_results(10).search()
        kwic = cq.kwic()
        print("Results: " + str(len(kwic.index)))
        df = df.append(kwic)
    display_df(df)

# one query (faster but should be carried out in portions)
bigOr = '|'.join(filtered_syns[0:500])

or_pattern = corpus_query(word=bigOr,pos='NEPER')
#print(or_pattern)

cq = create_corpus(corpus).pattern(or_pattern).max_results(1000).search()
kwic = cq.kwic()
display(HTML("<i>Results for big or</i>: " + str(len(kwic.index))))
df = df.append(kwic)
display_df(df)
# Out:
# Query URL: http://sk.taalbanknederlands.inl.nl/LexiconService/lexicon/expand?case_sensitive=false&tweaked_queries=true&database=nameslex&wordform=jan
# 179                 een grote droefheit ick kan       Hans  NEPER     hans
# 180                 wenst u l ende grietmartens        Jan  NEPER     ijan
# 181                       met mij uijt na rulef     Jansen  NEPER  ijansen
# 182             dese brief salmen bestellen aen       Hans  NEPER     hans
# 183                     seer en wel beminde man       Hans  NEPER     hans
# 184                 bryef aen den eersammen man        Jan  NEPER     ijan
# 185                 tegen ons mijn bemijnde man        Jan  NEPER     ijan
# 186                            te bestellen aen        Jan  NEPER      ian
# 187              geschreven aen min beminde man        Jan  NEPER      ian
# 188                      ben met ons kint antie       Jans  NEPER     ians
# 189                      doch soo ueel en seght        Jan  NEPER      ian
# 190               van mijn ue huisvrou geertrui       Jans  NEPER     ians
# 191           hondert duijsent goede nachten en        Jan  NEPER      ian
# 192            […]en uerer mijn lief ge[...]cht        Jan  NEPER      ian
#
#                                              right context
# 0                    louwerensen decker leggende mijt sijn
# 1                        deckers seght tegen klaes bartels
# 2                       louwerensz Decker Legende met sijn
# 3                                     Iongh gaen wan he na
# 4                       Deckens dietelof hendrick wrouw is
# 5                                     die sal se dan voort
# 6                            Claesen lalander laet u.l. op
# 7                              Claesen […] Jnder dooet soo
# 8                   toebeiassen brijef stack twelleke mijn
# 9                  toebeiassen brief geesloeten voors ijck
# 10                            gillesen sij ben gecoome van
# 11                                genaemt godt lof ben tot
# 12                          pietersen Varende op het schip
# 13                    Pietersen Beminde man, naar Jonstige
# 14                                  en hebben wij tot noch
# 15                                 en aspelgren is ok tuys
# 16                                soo hem bij occasie vint
# 17
# 18                                 van galen aen karsov om
# 19                                    varen de op het sijp
# 20                                 van galen aen karsov om
# 21                                  en anten en alle goede
# 22                      varende voor trompetter met vrient
# 23                               ick ul huijs frou neeltie
# 24                            bewaere en bescherme voor al
# 25                             die gaet nu op boonemaecken
# 26                                 ioppen uven soon in den
# 27                      luickesen kerremelc van moncke dam
# 28                              van haerlijm dije lijdt te
# 29                         sijckes van stavooren met vrijn
# ..                                                     ...
# 163                                sijn wijf die seijt dat
# 164                              iansse sijn vrou en kijnt
# 165                                  neef het sterft nu so
# 166                      france trompetter vaerende op het
# 167                             france ick vl beminde huus
# 168                        hendericks mijn beminde man ick
# 169  teijssen schounmaker</anders> een hartelicke grotenis
# 170                          tijesen soo ghij noch gesoont
# 171                                    heeft se ende js op
# 172                             Is nou heel gebeetert ende
# 173                henderickse vaerende voor bootsgesel op
# 174                       henderickse u l mijne gesonthijt
# 175               hendericksen vaerende voor bootsgesel op
# 176                               henderickse ick laet u l
# 177                      sijn vrijster ijannetien ijs noch
# 178                                 winkel is oock doot to
# 179                            meiier niet in huis belopen
# 180                          oock veel duisent goede nacht
# 181                                       d dije s ijs ock
# 182                      pieterse seijlemaker varen op het
# 183                                  pieterse ick laet u l
# 184                      wijllemse luijtenant op het schep
# 185                                wijllemse ijck laet u l
# 186                  ariiense van den brock certiermeester
# 187                         ariiense vanden brock ick laet
# 188                                godt hebbe lof voor sin
# 189                       willemsen ueel goest uan minnent
# 190                                  die mof waer hier bij
# 191                             wilmsen en vader en moeder
# 192                            maertense de brun sijn vrou
#
# [193 rows x 5 columns]
# HBox(children=(Label(value='Sla uw resultaten op:'), Text(value='mijn_resultaten.csv'), Button(button_style='w…
